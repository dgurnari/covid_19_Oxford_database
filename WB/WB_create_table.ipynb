# %% [markdown]
# # INFO

# %% [markdown]
# This notebook contains all the required code to fetch, process and merge data in order to populate the World Bank table.

# %% [markdown]
# # Word Bank

# %%
import numpy as np
import pandas as pd

from io import BytesIO
from zipfile import ZipFile
from urllib.request import urlopen

# %%
def download_WDIdata_to_df(url):
    print("Dowloading")
    resp = urlopen(url)
    zipfile = ZipFile(BytesIO(resp.read()))
    print("Downloaded")

    print("Loading into a pandas dataframe")
    data = pd.read_csv(zipfile.open('WDIData.csv'))
    print("Dataframe created")

    return data

# %%
def load_local_WDIdata(zip_path):
    print("loading data from ", zip_path)
    zipfile = ZipFile(zip_path)
    data = pd.read_csv(zipfile.open('WDIData.csv'))
    print("Dataframe created")

    return data

# %% [markdown]
# ### Loads the data

# %%
DOWNLOAD_ZIP = True

# %%
if DOWNLOAD_ZIP:
    ZIP_URL = "http://databank.worldbank.org/data/download/WDI_csv.zip"
    # it can take some minutes
    wb_df = download_WDIdata_to_df(ZIP_URL)

else:
    ZIP_PATH = ('input/wb/WDI_csv.zip')
    wb_df = load_local_WDIdata(ZIP_PATH)
# Out:
# Dowloading
# Downloaded
# Loading into a pandas dataframe
# Dataframe created

# %%
# remove the last column (always empty)
wb_df.drop("Unnamed: 64", axis=1, inplace=True)

# %%
wb_df["source"] = "World Bank"
wb_df["date"] = "2020-07-01"
wb_df["adm_area_1"] = None
wb_df["adm_area_2"] = None
wb_df["adm_area_3"] = None

# %%
wb_df.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 4  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2015       2016       2017  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  84.171599  84.510171        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...  88.720097  89.308602  90.283638
# 2   NaN   NaN   NaN   NaN   NaN  ...  78.211000  79.065508  81.102134
# 3   NaN   NaN   NaN   NaN   NaN  ...  96.936319  97.290083  97.467915
# 4   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN  37.165211
#
#         2018  2019      source        date  adm_area_1  adm_area_2  adm_area_3
# 0        NaN   NaN  World Bank  2020-07-01        None        None        None
# 1  89.286856   NaN  World Bank  2020-07-01        None        None        None
# 2  79.248100   NaN  World Bank  2020-07-01        None        None        None
# 3  97.063959   NaN  World Bank  2020-07-01        None        None        None
# 4        NaN   NaN  World Bank  2020-07-01        None        None        None
#
# [5 rows x 69 columns]

# %% [markdown]
# ### Select only countries with valid ISO (drop things like Arab World and EU) and add GID

# %%
# load the full list of countries with a GID
gid_list = pd.read_csv("input/gid/admn_0.csv")

# consider only the rows with a valid GID
wb_GID = wb_df[wb_df["Country Code"].isin(gid_list["countrycode"])].copy()

# add a GID column
wb_GID["GID"] = wb_GID["Country Code"]

# %%
# rearrange the columns
cols = list(wb_GID.columns)
wb_GID = wb_GID[cols[-6:-4] + [cols[-1]] + cols[:2] + cols[-4:-1] + cols[2:4] + cols[4:-6]]

# %%
# we do not consider those
wb_NOT = wb_df[~wb_df["Country Code"].isin(gid_list["countrycode"])].copy()
wb_NOT["Country Name"].unique()
# Out:
# array(['Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Middle East & North Africa',
#        'Middle East & North Africa (excluding high income)',
#        'Middle East & North Africa (IDA & IBRD countries)',
#        'Middle income', 'North America', 'Not classified', 'OECD members',
#        'Other small states', 'Pacific island small states',
#        'Post-demographic dividend', 'Pre-demographic dividend',
#        'Small states', 'South Asia', 'South Asia (IDA & IBRD)',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)',
#        'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income',
#        'World', 'Channel Islands', 'Kosovo'], dtype=object)

# %%
wb_GID.head()
# Out:
#            source        date  GID Country Name Country Code adm_area_1  \
# 67257  World Bank  2020-07-01  AFG  Afghanistan          AFG       None
# 67258  World Bank  2020-07-01  AFG  Afghanistan          AFG       None
# 67259  World Bank  2020-07-01  AFG  Afghanistan          AFG       None
# 67260  World Bank  2020-07-01  AFG  Afghanistan          AFG       None
# 67261  World Bank  2020-07-01  AFG  Afghanistan          AFG       None
#
#       adm_area_2 adm_area_3  \
# 67257       None       None
# 67258       None       None
# 67259       None       None
# 67260       None       None
# 67261       None       None
#
#                                           Indicator Name     Indicator Code  \
# 67257  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 67258            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 67259  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 67260  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 67261  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS
#
#        ...     2010       2011       2012       2013       2014       2015  \
# 67257  ...  20.6800  22.330000  24.080000  26.170000  27.990000  30.100000
# 67258  ...  42.7000  43.222019  69.100000  68.933266  89.500000  71.500000
# 67259  ...  30.2188  29.572881  60.849157  61.282199  86.500512  64.573354
# 67260  ...  82.8000  86.567779  95.000000  92.673767  98.700000  92.500000
# 67261  ...      NaN   9.005013        NaN        NaN   9.961000        NaN
#
#            2016       2017        2018  2019
# 67257  32.44000        NaN         NaN   NaN
# 67258  97.70000  97.700000   98.713203   NaN
# 67259  97.09936  97.091973   98.272872   NaN
# 67260  99.50000  99.500000  100.000000   NaN
# 67261       NaN  14.893312         NaN   NaN
#
# [5 rows x 70 columns]

# %% [markdown]
# ### Save to CSV

# %%
wb_GID.to_csv("WB_full_table.csv", index = False)

# %% [markdown]
# ## Parse the data, for each row keep only the most recent value

# %%
wb_data = wb_GID.copy()

# load the indicators we are interested in
# CODES_PATH = 'input/wb/interesting_indicators.csv'
# interesting_indicators = pd.read_csv(CODES_PATH)
# wb_data = wb_df.loc[wb_df["Indicator Code"].isin(interesting_indicators["code"])].copy()

# the last column name is the most recent year
most_recent_year = int(wb_data.columns[-1])

# creates two additional columns
wb_data.loc[:, "Most Recent Value"] = np.nan
wb_data.loc[:, "Year"] = np.nan

# for each row, find the most recent non NaN measure
for year in range(most_recent_year, 1959, -1):
    if wb_data["Most Recent Value"].isnull().values.any():
        wb_data.loc[wb_data["Most Recent Value"].isnull(), "Year"] = int(year)
        wb_data.loc[: ,"Most Recent Value"].fillna(wb_data[str(year)], inplace=True)
    else:
        break

# drop all the colums with years
cols_to_drop = [str(year) for year in range(1960, most_recent_year+1)]

wb_data_recent = wb_data.drop(cols_to_drop, axis=1)

# %%
wb_data_recent.head()
# Out:
#            source        date  GID Country Name Country Code adm_area_1  \
# 67257  World Bank  2020-07-01  AFG  Afghanistan          AFG       None
# 67258  World Bank  2020-07-01  AFG  Afghanistan          AFG       None
# 67259  World Bank  2020-07-01  AFG  Afghanistan          AFG       None
# 67260  World Bank  2020-07-01  AFG  Afghanistan          AFG       None
# 67261  World Bank  2020-07-01  AFG  Afghanistan          AFG       None
#
#       adm_area_2 adm_area_3  \
# 67257       None       None
# 67258       None       None
# 67259       None       None
# 67260       None       None
# 67261       None       None
#
#                                           Indicator Name     Indicator Code  \
# 67257  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 67258            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 67259  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 67260  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 67261  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS
#
#        Most Recent Value    Year
# 67257          32.440000  2016.0
# 67258          98.713203  2018.0
# 67259          98.272872  2018.0
# 67260         100.000000  2018.0
# 67261          14.893312  2017.0

# %% [markdown]
# ### Save to CSV

# %%
wb_data_recent.to_csv("WB_most_recent_values.csv", index=False)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
