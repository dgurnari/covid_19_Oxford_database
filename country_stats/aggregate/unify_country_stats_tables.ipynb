# %%
import numpy as np
import pandas as pd
import json

# %% [markdown]
# # Word Bank

# %% [markdown]
# ## We need to aggregate the data

# %%
wb_data = pd.read_csv("data/wb_out_FULL.csv")
wb_data
# Out:
#       Country Name Country Code  \
# 0      Afghanistan          AFG
# 1      Afghanistan          AFG
# 2      Afghanistan          AFG
# 3      Afghanistan          AFG
# 4      Afghanistan          AFG
# ...            ...          ...
# 14185     Zimbabwe          ZWE
# 14186     Zimbabwe          ZWE
# 14187     Zimbabwe          ZWE
# 14188     Zimbabwe          ZWE
# 14189     Zimbabwe          ZWE
#
#                                           Indicator Name  \
# 0                Access to electricity (% of population)
# 1      Adequacy of social insurance programs (% of to...
# 2      Adjusted net enrollment rate, primary (% of pr...
# 3      Adjusted net enrollment rate, primary, female ...
# 4      Adjusted net enrollment rate, primary, male (%...
# ...                                                  ...
# 14185                              Surface area (sq. km)
# 14186                                   Urban population
# 14187           Urban population (% of total population)
# 14188                 Urban population growth (annual %)
# 14189  Vulnerable employment, total (% of total emplo...
#
#                  Indicator Code  Most Recent Value    Year  GID
# 0                EG.ELC.ACCS.ZS       9.770000e+01  2017.0  AFG
# 1      per_si_allsi.adq_pop_tot       1.569503e+01  2007.0  AFG
# 2                   SE.PRM.TENR       2.676600e+01  1993.0  AFG
# 3                SE.PRM.TENR.FE       1.369764e+01  1993.0  AFG
# 4                SE.PRM.TENR.MA       3.879503e+01  1993.0  AFG
# ...                         ...                ...     ...  ...
# 14185            AG.SRF.TOTL.K2       3.907600e+05  2018.0  ZWE
# 14186               SP.URB.TOTL       4.650663e+06  2018.0  ZWE
# 14187         SP.URB.TOTL.IN.ZS       3.220900e+01  2018.0  ZWE
# 14188               SP.URB.GROW       1.323892e+00  2018.0  ZWE
# 14189            SL.EMP.VULN.ZS       6.473900e+01  2019.0  ZWE
#
# [14190 rows x 7 columns]

# %%
wb_data["Most Recent Value"] = wb_data["Most Recent Value"].fillna("")

# %%
properties = []
for idx, row in wb_data.iterrows():
    properties.append({row["Indicator Code"]: {"Indicator Name": row["Indicator Name"],
                                               "Most Recent Value": row["Most Recent Value"],
                                               "Year": row["Year"]
    }})

wb_data["properties"] = properties

# %%
wb_data.drop(["Indicator Code", "Indicator Name", "Most Recent Value", "Year"], axis=1, inplace=True)

# %%
def merge_list_of_dict(l):
    d = {}
    for elem in l:
        d.update(elem)
    return d

# %%
wb_data_aggr = wb_data.groupby(["Country Name", "Country Code", "GID"]).agg({'properties':lambda x: merge_list_of_dict(list(x))}).reset_index()

# %%
# convert the GID to list
wb_data_aggr.GID = wb_data_aggr.GID.apply(lambda x: [x])
# rename some columns
wb_data_aggr = wb_data_aggr.rename(columns={"GID": "gid",
                                            "properties": "Properties",
                                            "Country Code":"Country ISO3"})
wb_data_aggr
# Out:
#               Country Name Country ISO3    gid  \
# 0              Afghanistan          AFG  [AFG]
# 1                  Albania          ALB  [ALB]
# 2                  Algeria          DZA  [DZA]
# 3           American Samoa          ASM  [ASM]
# 4                  Andorra          AND  [AND]
# ..                     ...          ...    ...
# 210  Virgin Islands (U.S.)          VIR  [VIR]
# 211     West Bank and Gaza          PSE  [PSE]
# 212            Yemen, Rep.          YEM  [YEM]
# 213                 Zambia          ZMB  [ZMB]
# 214               Zimbabwe          ZWE  [ZWE]
#
#                                             Properties
# 0    {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...
# 1    {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...
# 2    {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...
# 3    {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...
# 4    {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...
# ..                                                 ...
# 210  {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...
# 211  {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...
# 212  {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...
# 213  {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...
# 214  {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...
#
# [215 rows x 4 columns]

# %%
# add source, year and samplesize column
wb_data_aggr["Source"] = "WB"
wb_data_aggr["Year"] = 2020
wb_data_aggr["Sample Size"] = -1
wb_data_aggr["adm level"] = 0
wb_data_aggr
# Out:
#               Country Name Country ISO3    gid  \
# 0              Afghanistan          AFG  [AFG]
# 1                  Albania          ALB  [ALB]
# 2                  Algeria          DZA  [DZA]
# 3           American Samoa          ASM  [ASM]
# 4                  Andorra          AND  [AND]
# ..                     ...          ...    ...
# 210  Virgin Islands (U.S.)          VIR  [VIR]
# 211     West Bank and Gaza          PSE  [PSE]
# 212            Yemen, Rep.          YEM  [YEM]
# 213                 Zambia          ZMB  [ZMB]
# 214               Zimbabwe          ZWE  [ZWE]
#
#                                             Properties Source  Year  \
# 0    {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB  2020
# 1    {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB  2020
# 2    {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB  2020
# 3    {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB  2020
# 4    {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB  2020
# ..                                                 ...    ...   ...
# 210  {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB  2020
# 211  {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB  2020
# 212  {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB  2020
# 213  {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB  2020
# 214  {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB  2020
#
#      Sample Size  adm level
# 0             -1          0
# 1             -1          0
# 2             -1          0
# 3             -1          0
# 4             -1          0
# ..           ...        ...
# 210           -1          0
# 211           -1          0
# 212           -1          0
# 213           -1          0
# 214           -1          0
#
# [215 rows x 8 columns]

# %% [markdown]
# # IVS_country

# %%
IVS_country = pd.read_pickle("data/IVS_country_GID.pkl")
IVS_country = IVS_country.rename(columns={"Survey": "Source",
                                          "Wave": "Year"})
IVS_country.drop("Country Numeric", axis=1, inplace=True)
IVS_country["adm level"] = 0
IVS_country
# Out:
#     Source       Year                    Country Name Country ISO3  \
# 0      EVS  1981-1984                         Belgium          BEL
# 1      EVS  1981-1984                          Canada          CAN
# 2      EVS  1981-1984                         Denmark          DNK
# 3      EVS  1981-1984                          France          FRA
# 4      EVS  1981-1984                         Germany          DEU
# ..     ...        ...                             ...          ...
# 361    WVS  2010-2014                           Egypt          EGY
# 362    WVS  2010-2014  United States of America (the)          USA
# 363    WVS  2010-2014                         Uruguay          URY
# 364    WVS  2010-2014                      Uzbekistan          UZB
# 365    WVS  2010-2014                           Yemen          YEM
#
#      Sample Size    gid                                         Properties  \
# 0           1145  [BEL]  {'A001': {'Label': 'Important in life: Family'...
# 1           1254  [CAN]  {'A001': {'Label': 'Important in life: Family'...
# 2           1182  [DNK]  {'A001': {'Label': 'Important in life: Family'...
# 3           1200  [FRA]  {'A001': {'Label': 'Important in life: Family'...
# 4           1305  [DEU]  {'A001': {'Label': 'Important in life: Family'...
# ..           ...    ...                                                ...
# 361         1523  [EGY]  {'A001': {'Label': 'Important in life: Family'...
# 362         2232  [USA]  {'A001': {'Label': 'Important in life: Family'...
# 363         1000  [URY]  {'A001': {'Label': 'Important in life: Family'...
# 364         1500  [UZB]  {'A001': {'Label': 'Important in life: Family'...
# 365         1000  [YEM]  {'A001': {'Label': 'Important in life: Family'...
#
#      adm level
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 361          0
# 362          0
# 363          0
# 364          0
# 365          0
#
# [358 rows x 8 columns]

# %% [markdown]
# # IVS_region

# %%
IVS_region = pd.read_pickle("data/IVS_region_GID.pkl")
IVS_region = IVS_region.rename(columns={"Survey": "Source",
                                          "Wave": "Year"})
IVS_region.drop("Country Numeric", axis=1, inplace=True)
IVS_region["adm level"] = 1
IVS_region
# Out:
#     Source       Year                                       Country Name  \
# 0      WVS  1999-2004                                         Bangladesh
# 1      WVS  1999-2004                                         Bangladesh
# 2      WVS  1999-2004                                         Bangladesh
# 3      WVS  1999-2004                                         Bangladesh
# 4      WVS  1999-2004                                         Bangladesh
# ..     ...        ...                                                ...
# 470    EVS  2008-2010  United Kingdom of Great Britain and Northern I...
# 471    EVS  2008-2010  United Kingdom of Great Britain and Northern I...
# 472    EVS  2008-2010  United Kingdom of Great Britain and Northern I...
# 473    EVS  2008-2010  United Kingdom of Great Britain and Northern I...
# 474    EVS  2008-2010                                      North Ireland
#
#     Country ISO3  Sample Size  \
# 0            BGD          199
# 1            BGD          121
# 2            BGD          105
# 3            BGD          128
# 4            BGD           81
# ..           ...          ...
# 470          GBR           22
# 471          GBR           43
# 472          GBR           43
# 473          GBR            6
# 474      GBR-NIR          500
#
#                                                    gid  \
# 0                                          [BGD.3.1_1]
# 1                                          [BGD.2.4_1]
# 2                                          [BGD.1.2_1]
# 3                                         [BGD.3.10_1]
# 4                                         [BGD.3.17_1]
# ..                                                 ...
# 470  [GBR.4.13_1, GBR.4.15_1, GBR.4.5_1, GBR.4.21_1...
# 471  [GBR.3.3_1, GBR.3.5_1, GBR.3.7_1, GBR.3.10_1, ...
# 472  [GBR.3.4_1, GBR.3.6_1, GBR.3.8_1, GBR.3.9_1, G...
# 473  [GBR.3.4_1, GBR.3.13_1, GBR.3.17_1, GBR.3.20_1...
# 474                                          [GBR.2_1]
#
#                                             Properties  adm level
# 0    {'original region code': {'Region Numeric': 50...          1
# 1    {'original region code': {'Region Numeric': 50...          1
# 2    {'original region code': {'Region Numeric': 50...          1
# 3    {'original region code': {'Region Numeric': 50...          1
# 4    {'original region code': {'Region Numeric': 50...          1
# ..                                                 ...        ...
# 470  {'original region code': {'Region Numeric': -5...          1
# 471  {'original region code': {'Region Numeric': -5...          1
# 472  {'original region code': {'Region Numeric': -5...          1
# 473  {'original region code': {'Region Numeric': -5...          1
# 474  {'original region code': {'Region Numeric': -5...          1
#
# [475 rows x 8 columns]

# %% [markdown]
# # Unify the data

# %%
country_statistics = pd.concat([wb_data_aggr, IVS_country, IVS_region], ignore_index=True)
country_statistics.to_pickle("to_upload/country_statistics.pkl")
country_statistics
# Out:
#                                            Country Name Country ISO3  \
# 0                                           Afghanistan          AFG
# 1                                               Albania          ALB
# 2                                               Algeria          DZA
# 3                                        American Samoa          ASM
# 4                                               Andorra          AND
# ...                                                 ...          ...
# 1043  United Kingdom of Great Britain and Northern I...          GBR
# 1044  United Kingdom of Great Britain and Northern I...          GBR
# 1045  United Kingdom of Great Britain and Northern I...          GBR
# 1046  United Kingdom of Great Britain and Northern I...          GBR
# 1047                                      North Ireland      GBR-NIR
#
#                                                     gid  \
# 0                                                 [AFG]
# 1                                                 [ALB]
# 2                                                 [DZA]
# 3                                                 [ASM]
# 4                                                 [AND]
# ...                                                 ...
# 1043  [GBR.4.13_1, GBR.4.15_1, GBR.4.5_1, GBR.4.21_1...
# 1044  [GBR.3.3_1, GBR.3.5_1, GBR.3.7_1, GBR.3.10_1, ...
# 1045  [GBR.3.4_1, GBR.3.6_1, GBR.3.8_1, GBR.3.9_1, G...
# 1046  [GBR.3.4_1, GBR.3.13_1, GBR.3.17_1, GBR.3.20_1...
# 1047                                          [GBR.2_1]
#
#                                              Properties Source       Year  \
# 0     {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB       2020
# 1     {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB       2020
# 2     {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB       2020
# 3     {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB       2020
# 4     {'EG.ELC.ACCS.ZS': {'Indicator Name': 'Access ...     WB       2020
# ...                                                 ...    ...        ...
# 1043  {'original region code': {'Region Numeric': -5...    EVS  2008-2010
# 1044  {'original region code': {'Region Numeric': -5...    EVS  2008-2010
# 1045  {'original region code': {'Region Numeric': -5...    EVS  2008-2010
# 1046  {'original region code': {'Region Numeric': -5...    EVS  2008-2010
# 1047  {'original region code': {'Region Numeric': -5...    EVS  2008-2010
#
#       Sample Size  adm level
# 0              -1          0
# 1              -1          0
# 2              -1          0
# 3              -1          0
# 4              -1          0
# ...           ...        ...
# 1043           22          1
# 1044           43          1
# 1045           43          1
# 1046            6          1
# 1047          500          1
#
# [1048 rows x 8 columns]

# %% [markdown]
# # Create table and upload the data

# %%
import pandas as pd
import json
import psycopg2

# %%
def create_country_stats_table(cur):
    sql_create_country_stats_table = """ 
        CREATE TABLE IF NOT EXISTS country_statistics (
            source text NOT NULL,
            year text NOT NULL,
            country text NOT NULL,
            countrycode text NOT NULL, 
            adm_level text NOT NULL,
            gid text[] NOT NULL,
            samplesize int,
            properties jsonb NOT NULL,
            UNIQUE (gid, source, year, adm_level),
            PRIMARY KEY (gid, source, year, adm_level)
        )"""

    cur.execute(sql_create_country_stats_table)

    print("country_statistics table created")

# %%
def drop_country_stats_table(cur):
    sql_drop_country_stats_table = """DROP TABLE country_statistics"""
    
    try:
        cur.execute(sql_drop_country_stats_table)
        print("country_statistics table deleted")
    except:
        print("country_statistics not present")

# %%
def import_data(cur,data):
    
    INSERT_STATEMENT = 'INSERT INTO country_statistics \
                            (source, year, \
                             country, countrycode,  \
                             adm_level, \
                             gid, samplesize, \
                             properties) \
                        VALUES (%s, %s, \
                                # %s, %s, \
                                # %s, \
                                # %s, %s, \
                                # %s);'
    

    for idx, row in data.iterrows():
        cur.execute(INSERT_STATEMENT, (row['Source'], row['Year'],
                                       row['Country Name'], row['Country ISO3'], 
                                       row['adm level'],
                                       row['gid'], row['Sample Size'], 
                                       json.dumps(row["Properties"])))

# %%
# Connect to covid19db.org
conn = psycopg2.connect(
    host='covid19db.org',
    port=5432,
    dbname='covid19db_adm_play',
    user='covid19db_adm_rw',
    password='fGt962FdeG2yXj3c4d3'
)

cur = conn.cursor()

# %%
# loads data from csv
country_stats = pd.read_pickle("to_upload/country_statistics.pkl")
type(country_stats.gid[0])
# Out:
# list

# %%
drop_country_stats_table(cur)
conn.commit()

create_country_stats_table(cur)
conn.commit()

import_data(cur, country_statistics)
conn.commit()
print("data uploaded")
# Out:
# country_statistics table deleted
# country_statistics table created
# data uploaded

# %% [markdown]
# # TEST

# %%
# Connect to covid19db.org
conn = psycopg2.connect(
    host='covid19db.org',
    port=5432,
    dbname='covid19db_adm_play',
    user='covid19db_adm_rw',
    password='fGt962FdeG2yXj3c4d3'
)

cur = conn.cursor()

# %%
cur.execute("""SELECT * FROM country_statistics""")

data = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
data
# Out:
#      source       year                                            country  \
# 0        WB       2020                                        Afghanistan
# 1        WB       2020                                            Albania
# 2        WB       2020                                            Algeria
# 3        WB       2020                                     American Samoa
# 4        WB       2020                                            Andorra
# ...     ...        ...                                                ...
# 1043    EVS  2008-2010  United Kingdom of Great Britain and Northern I...
# 1044    EVS  2008-2010  United Kingdom of Great Britain and Northern I...
# 1045    EVS  2008-2010  United Kingdom of Great Britain and Northern I...
# 1046    EVS  2008-2010  United Kingdom of Great Britain and Northern I...
# 1047    EVS  2008-2010                                      North Ireland
#
#      countrycode adm_level                                                gid  \
# 0            AFG         0                                              [AFG]
# 1            ALB         0                                              [ALB]
# 2            DZA         0                                              [DZA]
# 3            ASM         0                                              [ASM]
# 4            AND         0                                              [AND]
# ...          ...       ...                                                ...
# 1043         GBR         1  [GBR.4.13_1, GBR.4.15_1, GBR.4.5_1, GBR.4.21_1...
# 1044         GBR         1  [GBR.3.3_1, GBR.3.5_1, GBR.3.7_1, GBR.3.10_1, ...
# 1045         GBR         1  [GBR.3.4_1, GBR.3.6_1, GBR.3.8_1, GBR.3.9_1, G...
# 1046         GBR         1  [GBR.3.4_1, GBR.3.13_1, GBR.3.17_1, GBR.3.20_1...
# 1047     GBR-NIR         1                                          [GBR.2_1]
#
#       samplesize                                         properties
# 0             -1  {'EN.POP.DNST': {'Year': 2018.0, 'Indicator Na...
# 1             -1  {'EN.POP.DNST': {'Year': 2018.0, 'Indicator Na...
# 2             -1  {'EN.POP.DNST': {'Year': 2018.0, 'Indicator Na...
# 3             -1  {'EN.POP.DNST': {'Year': 2018.0, 'Indicator Na...
# 4             -1  {'EN.POP.DNST': {'Year': 2018.0, 'Indicator Na...
# ...          ...                                                ...
# 1043          22  {'A001': {'Label': 'Important in life: Family'...
# 1044          43  {'A001': {'Label': 'Important in life: Family'...
# 1045          43  {'A001': {'Label': 'Important in life: Family'...
# 1046           6  {'A001': {'Label': 'Important in life: Family'...
# 1047         500  {'A001': {'Label': 'Important in life: Family'...
#
# [1048 rows x 8 columns]
